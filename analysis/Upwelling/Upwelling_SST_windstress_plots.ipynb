# %% [markdown]
# # CM4X part II: Upwelling section

# %% [markdown]
# ## SST and wind stress at the coast

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Observations:

# %% [markdown]
# https://chapman.ceoas.oregonstate.edu/scow/wind_stress_curl.html

# %% [markdown]
# ## load data from netcdf file

# %%
upwelling_data = xr.open_dataset("../../data/plotting_ready/results_upwelling_CM4X_paper.nc")

# %%
plt.rcParams.update({"font.size":12})
figsize=[6.5,4.0]
savefig_kws=dict(bbox_inches="tight", facecolor="white", dpi=400, format='jpeg')
degC= "$^{\circ}$C"

color_CM4Xp25 = "black"
color_CM4Xp125 = "brown"
color_obs = "blueviolet"
color_obs2 = "green"
color_CM4 = "blue"
color_CM4Xp25c96 = "orange"

# %%
# Use the same font as JAMES
dirstix = "../../fonts/stixfonts/fonts/static_ttf"
import matplotlib.font_manager as font_manager
for font in font_manager.findSystemFonts(dirstix):
    font_manager.fontManager.addfont(font)

# Set font family globally
plt.rcParams['font.family'] = 'STIX Two Text'

# %% [markdown]
# ## SST for EBUS

# %%
ccs_obs = upwelling_data["sst_ccs_OIv2"]
ccs_cm4x25 = upwelling_data["sst_ccs_CM4X-p25"]
ccs_cm4x25h = upwelling_data["sst_ccs_CM4X-p25hist"]
ccs_cm4x25c96h = upwelling_data["sst_ccs_CM4X-p25-c96"]
ccs_cm4x125 = upwelling_data["sst_ccs_CM4X-p125"]
ccs_cm4x125h = upwelling_data["sst_ccs_CM4X-p125hist"] 

peru_obs = upwelling_data["sst_peru_OIv2"]
peru_cm4x25 = upwelling_data["sst_peru_CM4X-p25"]
peru_cm4x25h = upwelling_data["sst_peru_CM4X-p25hist"]
peru_cm4x25c96h = upwelling_data["sst_peru_CM4X-p25-c96"]
peru_cm4x125 = upwelling_data["sst_peru_CM4X-p125"]
peru_cm4x125h = upwelling_data["sst_peru_CM4X-p125hist"] 

cana_obs = upwelling_data["sst_cana_OIv2"]
cana_cm4x25 = upwelling_data["sst_cana_CM4X-p25"]
cana_cm4x25h = upwelling_data["sst_cana_CM4X-p25hist"]
cana_cm4x25c96h = upwelling_data["sst_cana_CM4X-p25-c96"]
cana_cm4x125 = upwelling_data["sst_cana_CM4X-p125"]
cana_cm4x125h = upwelling_data["sst_cana_CM4X-p125hist"] 

beng_obs = upwelling_data["sst_beng_OIv2"]
beng_cm4x25 = upwelling_data["sst_beng_CM4X-p25"]
beng_cm4x25h = upwelling_data["sst_beng_CM4X-p25hist"]
beng_cm4x25c96h = upwelling_data["sst_beng_CM4X-p25-c96"]
beng_cm4x125 = upwelling_data["sst_beng_CM4X-p125"]
beng_cm4x125h = upwelling_data["sst_beng_CM4X-p125hist"]

# %%
fig, axs = plt.subplots(figsize=figsize, ncols=2, nrows=2)


common = dict(_labels=False, xincrease=False)
###------------------------- CCS -------------
# obs
ccs_obs.plot(ax=axs[0,0], label="NOAA OIv2", color=color_obs, **common)
# historical
ccs_cm4x25h.plot(ax=axs[0,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
ccs_cm4x125h.plot(ax=axs[0,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)
ccs_cm4x25c96h.plot(ax=axs[0,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)


###------------------------- PERU -------------
# obs
peru_obs.plot(ax=axs[1,0], label="NOAA OIv2", color=color_obs, **common)
# historical
peru_cm4x25h.plot(ax=axs[1,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
peru_cm4x125h.plot(ax=axs[1,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)
peru_cm4x25c96h.plot(ax=axs[1,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)

###------------------------- CANA -------------
# obs
cana_obs.plot(ax=axs[0,1], label="NOAA OIv2", color=color_obs, **common)
# historical
cana_cm4x25h.plot(ax=axs[0,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
cana_cm4x125h.plot(ax=axs[0,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)
cana_cm4x25c96h.plot(ax=axs[0,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)

###------------------------- BENG -------------
# obs
beng_obs.plot(ax=axs[1,1], label="NOAA OIv2", color=color_obs, **common)
# historical
beng_cm4x25h.plot(ax=axs[1,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
beng_cm4x125h.plot(ax=axs[1,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)
beng_cm4x25c96h.plot(ax=axs[1,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)

for ax in axs.flatten():
    ax.grid()
    ax.set_xticks([50000,100000,150000,200000,250000])
    ax.set_xticklabels([50,100,150,200,250])

axs[0,0].set_ylim([12,19])
axs[0,1].set_ylim([19,24])
axs[1,0].set_ylim([21,27])
axs[1,1].set_ylim([16,21])
axs[1,1].legend(fontsize=12, loc=3, framealpha=1.,
                bbox_to_anchor=[-0.9,-1.,0.1,0.1],
                ncol=2,
                markerfirst=False, markerscale=0,
               )
axs[0,0].text(108000, 17.8, "California", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,0].text(285000, 21.6, "Peru", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[0,1].text(80000, 23.2, "Canary", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,1].text(285000, 16.5, "Benguela", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))

fig.text(0.75, -0.32, "Distance to coast [km]", 
         fontsize=12,
         transform=axs[1,0].transAxes)

fig.text(-0.25, 0.3, f"Sea Surface Temperature [{degC}]",
         rotation="vertical", fontsize=12, color="k",
         transform=axs[1,0].transAxes)

plt.subplots_adjust(hspace=0.25, wspace=0.2)

plt.draw()
plt.savefig("../../figures/SST_summer_EBUS.jpeg", **savefig_kws)

# %% [markdown]
# ## ALL wind stress and curl in one

# %%
#-------- alongshore windstress ---------------

ws_ccs_obs = upwelling_data["taua_ccs_scow"]
ws_ccs_cm4x25 = upwelling_data["taua_ccs_CM4X-p25"]
ws_ccs_cm4x25h = upwelling_data["taua_ccs_CM4X-p25hist"]
ws_ccs_cm4x25c96h = upwelling_data["taua_ccs_CM4X-p25-c96"]
ws_ccs_cm4x125 = upwelling_data["taua_ccs_CM4X-p125"]
ws_ccs_cm4x125h = upwelling_data["taua_ccs_CM4X-p125hist"]

ws_peru_obs = upwelling_data["taua_peru_scow"]
ws_peru_cm4x25 = upwelling_data["taua_peru_CM4X-p25"]
ws_peru_cm4x25h = upwelling_data["taua_peru_CM4X-p25hist"]
ws_peru_cm4x25c96h = upwelling_data["taua_peru_CM4X-p25-c96"]
ws_peru_cm4x125 = upwelling_data["taua_peru_CM4X-p125"]
ws_peru_cm4x125h = upwelling_data["taua_peru_CM4X-p125hist"]

ws_cana_obs = upwelling_data["taua_cana_scow"]
ws_cana_cm4x25 = upwelling_data["taua_cana_CM4X-p25"]
ws_cana_cm4x25h = upwelling_data["taua_cana_CM4X-p25hist"]
ws_cana_cm4x25c96h = upwelling_data["taua_cana_CM4X-p25-c96"]
ws_cana_cm4x125 = upwelling_data["taua_cana_CM4X-p125"]
ws_cana_cm4x125h = upwelling_data["taua_cana_CM4X-p125hist"]

ws_beng_obs = upwelling_data["taua_beng_scow"]
ws_beng_cm4x25 = upwelling_data["taua_beng_CM4X-p25"]
ws_beng_cm4x25h = upwelling_data["taua_beng_CM4X-p25hist"]
ws_beng_cm4x25c96h = upwelling_data["taua_beng_CM4X-p25-c96"]
ws_beng_cm4x125 = upwelling_data["taua_beng_CM4X-p125"]
ws_beng_cm4x125h = upwelling_data["taua_beng_CM4X-p125hist"]

#-------- windstress curl ---------------
wc_ccs_obs = upwelling_data["curl_ccs_scow"]
wc_ccs_cm4x25 = upwelling_data["curl_ccs_CM4X-p25"]
wc_ccs_cm4x25h = upwelling_data["curl_ccs_CM4X-p25hist"]
wc_ccs_cm4x25c96h = upwelling_data["curl_ccs_CM4X-p25-c96"]
wc_ccs_cm4x125 = upwelling_data["curl_ccs_CM4X-p125"]
wc_ccs_cm4x125h = upwelling_data["curl_ccs_CM4X-p125hist"]

wc_peru_obs = upwelling_data["curl_peru_scow"]
wc_peru_cm4x25 = upwelling_data["curl_peru_CM4X-p25"]
wc_peru_cm4x25h = upwelling_data["curl_peru_CM4X-p25hist"]
wc_peru_cm4x25c96h = upwelling_data["curl_peru_CM4X-p25-c96"]
wc_peru_cm4x125 = upwelling_data["curl_peru_CM4X-p125"]
wc_peru_cm4x125h = upwelling_data["curl_peru_CM4X-p125hist"]

wc_cana_obs = upwelling_data["curl_cana_scow"]
wc_cana_cm4x25 = upwelling_data["curl_cana_CM4X-p25"]
wc_cana_cm4x25h = upwelling_data["curl_cana_CM4X-p25hist"]
wc_cana_cm4x25c96h = upwelling_data["curl_cana_CM4X-p25-c96"]
wc_cana_cm4x125 = upwelling_data["curl_cana_CM4X-p125"]
wc_cana_cm4x125h = upwelling_data["curl_cana_CM4X-p125hist"]

wc_beng_obs = upwelling_data["curl_beng_scow"]
wc_beng_cm4x25 = upwelling_data["curl_beng_CM4X-p25"]
wc_beng_cm4x25h = upwelling_data["curl_beng_CM4X-p25hist"]
wc_beng_cm4x25c96h = upwelling_data["curl_beng_CM4X-p25-c96"]
wc_beng_cm4x125 = upwelling_data["curl_beng_CM4X-p125"]
wc_beng_cm4x125h = upwelling_data["curl_beng_CM4X-p125hist"]

# %%
from matplotlib.offsetbox import AnchoredOffsetbox, TextArea, HPacker, VPacker

fig, axs = plt.subplots(figsize=figsize, ncols=2, nrows=2)

common = dict(_labels=False, xincrease=False)
nh = dict(yincrease=False)

taxs = axs.copy()
for j in range(2):
    for i in range(2):
        taxs[j,i] = axs[j,i].twinx()


###------------------------- CCS -------------

## alongshore stress
# obs
ws_ccs_obs.plot(ax=axs[0,0], label="SCOW", color=color_obs, **common, **nh)
# historical
ws_ccs_cm4x25h.plot(ax=axs[0,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common, **nh)
ws_ccs_cm4x25c96h.plot(ax=axs[0,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common, **nh)
ws_ccs_cm4x125h.plot(ax=axs[0,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common, **nh)

## wind stress curl
# obs
(1e7 * wc_ccs_obs).plot(ax=taxs[0,0], label="SCOW", color=color_obs, linestyle="--", **common)
# historical
(1e7 * wc_ccs_cm4x25h).plot(ax=taxs[0,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common)
(1e7 * wc_ccs_cm4x25c96h).plot(ax=taxs[0,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common)
(1e7 * wc_ccs_cm4x125h).plot(ax=taxs[0,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common)


###------------------------- PERU -------------

## alongshore stress
# obs
ws_peru_obs.plot(ax=axs[1,0], label="SCOW", color=color_obs, **common)
# historical
ws_peru_cm4x25h.plot(ax=axs[1,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
ws_peru_cm4x25c96h.plot(ax=axs[1,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)
ws_peru_cm4x125h.plot(ax=axs[1,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)

## wind stress curl
# obs
(1e7 * wc_peru_obs).plot(ax=taxs[1,0], label="SCOW", color=color_obs, linestyle="--", **common, **nh)
# historical
(1e7 * wc_peru_cm4x25h).plot(ax=taxs[1,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common, **nh)
(1e7 * wc_peru_cm4x25c96h).plot(ax=taxs[1,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common, **nh)
(1e7 * wc_peru_cm4x125h).plot(ax=taxs[1,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common, **nh)


###------------------------- CANA -------------

## alongshore stress
# obs
ws_cana_obs.plot(ax=axs[0,1], label="SCOW", color=color_obs, **common, **nh)
# historical
ws_cana_cm4x25h.plot(ax=axs[0,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common, **nh)
ws_cana_cm4x25c96h.plot(ax=axs[0,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common, **nh)
ws_cana_cm4x125h.plot(ax=axs[0,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common, **nh)

## wind stress curl
# obs
(1e7 * wc_cana_obs).plot(ax=taxs[0,1], label="SCOW", color=color_obs, linestyle="--", **common)
# historical
(1e7 * wc_cana_cm4x25h).plot(ax=taxs[0,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common)
(1e7 * wc_cana_cm4x25c96h).plot(ax=taxs[0,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common)
(1e7 * wc_cana_cm4x125h).plot(ax=taxs[0,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common)


###------------------------- BENG -------------

## alongshore stress
# obs
ws_beng_obs.plot(ax=axs[1,1], label="SCOW", color=color_obs, **common)
# historical
ws_beng_cm4x25h.plot(ax=axs[1,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
ws_beng_cm4x25c96h.plot(ax=axs[1,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)
# replace with historical when available
ws_beng_cm4x125h.plot(ax=axs[1,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)

## wind stress curl
# obs
(1e7 * wc_beng_obs).plot(ax=taxs[1,1], label="SCOW", color=color_obs, linestyle="--", **common, **nh)
# historical
(1e7 * wc_beng_cm4x25h).plot(ax=taxs[1,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common, **nh)
(1e7 * wc_beng_cm4x25c96h).plot(ax=taxs[1,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common, **nh)
(1e7 * wc_beng_cm4x125h).plot(ax=taxs[1,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common, **nh)


for ax in axs.flatten():
    ax.grid()
    ax.set_xticks([50000,100000,150000,200000,250000])
    ax.set_xticklabels([50,100,150,200,250])
    
    yticks_in = ax.get_yticks()
    yticks_out = [f"{x:.2f}" for x in yticks_in]
    ax.set_yticklabels(yticks_out, color="red")
    

for tax in taxs.flatten():
    yticks_in = tax.get_yticks()
    yticks_out = [f"{x:.0f}" for x in yticks_in]
    tax.set_yticklabels(yticks_out, color="blue")


fig.text(0.8, -0.35, "Distance to coast [km]", 
         fontsize=12,
         transform=axs[1,0].transAxes)

fig.text(-0.3, 0.3, "Alongshore wind stress [N/m2]",
         rotation="vertical", fontsize=12, color="red",
         transform=axs[1,0].transAxes)

fig.text(1.15, 0.25, "Wind stress curl [N/m2 per $10^{4}$ km]",
         rotation="vertical", fontsize=12, color="blue",
         transform=axs[1,1].transAxes)


axs[1,1].legend(fontsize=12, loc=3, framealpha=1.,
                bbox_to_anchor=[-0.9,-1.,0.1,0.1], ncol=2)

axs[0,0].text(280000, -0.05, "California", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,0].text(280000, 0.01, "Peru", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[0,1].text(280000, -0.05, "Canary", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,1].text(280000, 0.05, "Benguela", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))

plt.subplots_adjust(hspace=0.3, wspace=0.35)
plt.draw()
plt.savefig("../../figures/Alongshore_windstress_summer_EBUS.jpeg", **savefig_kws)

# %% [markdown]
# ## same thing with CMEMS for response to reviewers

# %%
upwelling_data_cmems = xr.open_dataset("../../data/plotting_ready/results_upwelling_CM4X_reviews.nc")

# %%
ws_ccs_obs_cmems = upwelling_data_cmems["taua_ccs_cmems"]
wc_ccs_obs_cmems = upwelling_data_cmems["curl_ccs_cmems"]

ws_peru_obs_cmems = upwelling_data_cmems["taua_peru_cmems"]
wc_peru_obs_cmems = upwelling_data_cmems["curl_peru_cmems"]

ws_cana_obs_cmems = upwelling_data_cmems["taua_cana_cmems"]
wc_cana_obs_cmems = upwelling_data_cmems["curl_cana_cmems"]

ws_beng_obs_cmems = upwelling_data_cmems["taua_beng_cmems"]
wc_beng_obs_cmems = upwelling_data_cmems["curl_beng_cmems"]

# %%
from matplotlib.offsetbox import AnchoredOffsetbox, TextArea, HPacker, VPacker

fig, axs = plt.subplots(figsize=figsize, ncols=2, nrows=2)

common = dict(_labels=False, xincrease=False)
nh = dict(yincrease=False)

taxs = axs.copy()
for j in range(2):
    for i in range(2):
        taxs[j,i] = axs[j,i].twinx()


###------------------------- CCS -------------

## alongshore stress
# obs
ws_ccs_obs.plot(ax=axs[0,0], label="SCOW", color=color_obs, **common, **nh)
ws_ccs_obs_cmems.plot(ax=axs[0,0], label="CMEMS", color=color_obs2, **common, **nh)
# historical
ws_ccs_cm4x25h.plot(ax=axs[0,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common, **nh)
ws_ccs_cm4x25c96h.plot(ax=axs[0,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common, **nh)
ws_ccs_cm4x125h.plot(ax=axs[0,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common, **nh)

## wind stress curl
# obs
(1e7 * wc_ccs_obs).plot(ax=taxs[0,0], label="SCOW", color=color_obs, linestyle="--", **common)
(1e7 * wc_ccs_obs_cmems).plot(ax=taxs[0,0], label="CMEMS", color=color_obs2, linestyle="--", **common)
# historical
(1e7 * wc_ccs_cm4x25h).plot(ax=taxs[0,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common)
(1e7 * wc_ccs_cm4x25c96h).plot(ax=taxs[0,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common)
(1e7 * wc_ccs_cm4x125h).plot(ax=taxs[0,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common)


###------------------------- PERU -------------

## alongshore stress
# obs
ws_peru_obs.plot(ax=axs[1,0], label="SCOW", color=color_obs, **common)
ws_peru_obs_cmems.plot(ax=axs[1,0], label="CMEMS", color=color_obs2, **common)
# historical
ws_peru_cm4x25h.plot(ax=axs[1,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
ws_peru_cm4x25c96h.plot(ax=axs[1,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)
ws_peru_cm4x125h.plot(ax=axs[1,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)

## wind stress curl
# obs
(1e7 * wc_peru_obs).plot(ax=taxs[1,0], label="SCOW", color=color_obs, linestyle="--", **common, **nh)
(1e7 * wc_peru_obs_cmems).plot(ax=taxs[1,0], label="CMEMS", color=color_obs2, linestyle="--", **common, **nh)
# historical
(1e7 * wc_peru_cm4x25h).plot(ax=taxs[1,0], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common, **nh)
(1e7 * wc_peru_cm4x25c96h).plot(ax=taxs[1,0], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common, **nh)
(1e7 * wc_peru_cm4x125h).plot(ax=taxs[1,0], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common, **nh)


###------------------------- CANA -------------

## alongshore stress
# obs
ws_cana_obs.plot(ax=axs[0,1], label="SCOW", color=color_obs, **common, **nh)
ws_cana_obs_cmems.plot(ax=axs[0,1], label="CMEMS", color=color_obs2, **common, **nh)
# historical
ws_cana_cm4x25h.plot(ax=axs[0,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common, **nh)
ws_cana_cm4x25c96h.plot(ax=axs[0,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common, **nh)
ws_cana_cm4x125h.plot(ax=axs[0,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common, **nh)

## wind stress curl
# obs
(1e7 * wc_cana_obs).plot(ax=taxs[0,1], label="SCOW", color=color_obs, linestyle="--", **common)
(1e7 * wc_cana_obs_cmems).plot(ax=taxs[0,1], label="CMEMS", color=color_obs2, linestyle="--", **common)
# historical
(1e7 * wc_cana_cm4x25h).plot(ax=taxs[0,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common)
(1e7 * wc_cana_cm4x25c96h).plot(ax=taxs[0,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common)
(1e7 * wc_cana_cm4x125h).plot(ax=taxs[0,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common)


###------------------------- BENG -------------

## alongshore stress
# obs
ws_beng_obs.plot(ax=axs[1,1], label="SCOW", color=color_obs, **common)
ws_beng_obs_cmems.plot(ax=axs[1,1], label="CMEMS", color=color_obs2, **common)
# historical
ws_beng_cm4x25h.plot(ax=axs[1,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="-", **common)
ws_beng_cm4x25c96h.plot(ax=axs[1,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="-", **common)
# replace with historical when available
ws_beng_cm4x125h.plot(ax=axs[1,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="-", **common)

## wind stress curl
# obs
(1e7 * wc_beng_obs).plot(ax=taxs[1,1], label="SCOW", color=color_obs, linestyle="--", **common, **nh)
(1e7 * wc_beng_obs_cmems).plot(ax=taxs[1,1], label="CMEMS", color=color_obs2, linestyle="--", **common, **nh)
# historical
(1e7 * wc_beng_cm4x25h).plot(ax=taxs[1,1], label="CM4X-p25", color=color_CM4Xp25, linestyle="--", **common, **nh)
(1e7 * wc_beng_cm4x25c96h).plot(ax=taxs[1,1], label="CM4X-p25-c96", color=color_CM4Xp25c96, linestyle="--", **common, **nh)
(1e7 * wc_beng_cm4x125h).plot(ax=taxs[1,1], label="CM4X-p125", color=color_CM4Xp125, linestyle="--", **common, **nh)


for ax in axs.flatten():
    ax.grid()
    ax.set_xticks([50000,100000,150000,200000,250000])
    ax.set_xticklabels([50,100,150,200,250])
    
    yticks_in = ax.get_yticks()
    yticks_out = [f"{x:.2f}" for x in yticks_in]
    ax.set_yticklabels(yticks_out, color="red")
    

for tax in taxs.flatten():
    yticks_in = tax.get_yticks()
    yticks_out = [f"{x:.0f}" for x in yticks_in]
    tax.set_yticklabels(yticks_out, color="blue")


fig.text(0.8, -0.35, "Distance to coast [km]", 
         fontsize=12,
         transform=axs[1,0].transAxes)

fig.text(-0.3, 0.3, "Alongshore wind stress [N/m2]",
         rotation="vertical", fontsize=12, color="red",
         transform=axs[1,0].transAxes)

fig.text(1.15, 0.25, "Wind stress curl [N/m2 per $10^{4}$ km]",
         rotation="vertical", fontsize=12, color="blue",
         transform=axs[1,1].transAxes)


axs[1,1].legend(fontsize=12, loc=3, framealpha=1.,
                bbox_to_anchor=[-0.9,-1.,0.1,0.1], ncol=2)

axs[0,0].text(280000, -0.05, "California", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,0].text(280000, 0.01, "Peru", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[0,1].text(280000, -0.05, "Canary", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))
axs[1,1].text(280000, 0.05, "Benguela", fontsize=12,
              bbox=dict(facecolor='white', alpha=1.0))

plt.subplots_adjust(hspace=0.3, wspace=0.35)
plt.draw()
plt.savefig("../../figures/Alongshore_windstress_summer_EBUS+CMEMS.jpeg", **savefig_kws)
